# %% [markdown]
# ### Hola Germán
# Para correr el programa dale en el botón donde dice RUN , si te equivocas dale en el cuadrado negro y le das a RUN otra vez

# %%
def formato(w, x, y, z):
    global mrgrsd, mrgcct
    print(w.rjust(10, ' ')+' | '+x)
    print('+'.rjust(12, ' ')+'------')
    print(y.rjust(mrgrsd, ' ')+'|'.rjust(mrgcct+1, ' ')+z)
    

def division(a, b):
    global r, c, i, j, mrgrsd, long_a, cct, rsd, a2, d, mrgcct
    e=b
    if i==0:
        d=a2[i]
        if d<e:
            print('\nComo '+d+' es menor que '+e+' tenemos que agarrar otro numero a la derecha')
            mrgrsd=mrgrsd+1
            mrgcct=mrgcct-1
            j=j+1
            d=d+a[j]
    print('\nNecesitamos un numero que multiplicado por '+e+' sea igual o menor a '+d)
    print('\nCual es ese número?')
    f=input()
    c=int(d)//int(e)
    cct=cct+str(c)
    while int(f)!=c:
        print('\nNo es el número que estamos buscando...\nIntenta nuevamente')
        f=input()
    print('\nCorrecto!!!\n\nAhora cuanto nos queda de residuo?')
    h=input()
    r=int(d)%int(e)
    rsd.append(str(r))
    i=i+1
    while int(h)!=r:
        print('\nNo es el número que estamos buscando...\nIntenta nuevamente')
        h=input()
    print('\nCorrecto!!!')

def bajar_numero(x, y):
    global a2, rsd, i, d, j
    if j<(long_a):
        i=i+1
        d=y
        d=d+a2[j]
        rsd.append(d)
        print('Bajamos el '+a2[j]+' para continuar con la división:\n\nPresiona ENTER para continuar')
        q=input()

print('Hola Germán!!!\n\nEl formato es el siguiente:\n\n"a" dividido entre "b"\n\nPor favor introduce el número "a"')
a=input()
a2=a
long_a=len(a)
mrgcct=len(a)
print('\nAhora introduce el número "b"')
b=input()
if int(b)==0:
    print('\nPor favor introduce un número mayor a 0')
    b=input()
c=''
d=''
r=''
cct=''
rsd=[' ']
i=0
j=0
mrgrsd=11-long_a
print('\nMuy bien, vamos a hacer la siguiente división:\n')
while j<(long_a):
    formato(a2, b, rsd[i], cct)
    division(a2, b)
    formato(a2, b, rsd[i], cct)
    j=j+1
    bajar_numero(a2, rsd[i])
    mrgrsd=mrgrsd+1
    mrgcct=mrgcct-1
    a=rsd[i]
print('\n\nEstamos listos Germán...')
# Out:
# Hola Germán!!!
#
# El formato es el siguiente:
#
# "a" dividido entre "b"
#
# Por favor introduce el número "a"
# 457
#
# Ahora introduce el número "b"
# 3
#
# Muy bien, vamos a hacer la siguiente división:
#
#        457 | 3
#            +------
#            |
#
# Necesitamos un numero que multiplicado por 3 sea igual o menor a 4
#
# Cual es ese número?
# 1
#
# Correcto!!!
#
# Ahora cuanto nos queda de residuo?
# 1
#
# Correcto!!!
#        457 | 3
#            +------
#        1   |1
# Bajamos el 5 para continuar con la división:
#
# Presiona ENTER para continuar
#
#        457 | 3
#            +------
#        15  |1
#
# Necesitamos un numero que multiplicado por 3 sea igual o menor a 15
#
# Cual es ese número?
# 5
#
# Correcto!!!
#
# Ahora cuanto nos queda de residuo?
# 0
#
# Correcto!!!
#        457 | 3
#            +------
#         0  |15
# Bajamos el 7 para continuar con la división:
#
# Presiona ENTER para continuar
#
#        457 | 3
#            +------
#         07 |15
#
# Necesitamos un numero que multiplicado por 3 sea igual o menor a 07
#
# Cual es ese número?
# 1
#
# No es el número que estamos buscando...
# Intenta nuevamente
# 2
#
# Correcto!!!
#
# Ahora cuanto nos queda de residuo?
# 1
#
# Correcto!!!
#        457 | 3
#            +------
#          1 |152
#
#
# Estamos listos Germán...
